# %%
# --------------------------------------------------------------#
# Projeto: Inteface Visual -  IHC Interaçao Humano Máquina
# usando python
# Progrmador : Nilton Barbosa Santos Filho
# Coordenadas Retiradas do Google Maps Brasil

# Bibliotecas usadas
import folium
import branca
import os
import json
import numpy as np
from folium import IFrame
import pandas as pd
import numpy.ma as ma
import base64
import matplotlib.pyplot as pltfrom 


# Configurar a imagem
from branca.element import Figure
figMapa = Figure(height=600, width=800)

# Coletando localizacao do mapa    
latitude_bahia=-12.3105
longitude_bahia=-39.1827



bahia = folium.Map(location=[latitude_bahia,longitude_bahia],zoom_start=7.5,control_scale=True)
bahia

# Localizaçao dos IFBA

icone = folium.Icon(color='green')
ifba_nome = "IFBA - Campus Simões Filho"
latitude_ifba = -12.794776842385133
longitude_ifba = -38.356516858879075
htmlcode = """<div>
              <img src="IFBASF.jpg" alt="IFBA - Campus Simões Filho" width="230" height="172">
              <br /><span>IFBA - Campus Simões Filho</span></div>"""
tooltip = "IFBA - Campus Simões Filho"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)


icone = folium.Icon(color='green')
ifba_nome = "IFBA - Lauro de Freitas"
latitude_ifba = -12.880450057123854
longitude_ifba =-38.31860598628614
htmlcode = """<div>
              <img src="IFBALF.jpg" alt="IFBA - Lauro de Freitas" width="230" height="172">
              <br /><span>IFBA - Lauro de Freitas</span></div>"""
tooltip = "IFBA - Lauro de Freitas"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)


icone = folium.Icon(color='green')
ifba_nome = "IFBA - Campus Salvador"
latitude_ifba = -12.950231017513818
longitude_ifba =-38.46428710768859
htmlcode = """<div>
              <img src="IFBASSA.jpg" alt="IFBA - Campus Salvador" width="230" height="172">
              <br /><span>IFBA - Campus Salvador</span></div>"""
tooltip = "IFBA - Campus Salvador"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)




icone = folium.Icon(color='green')
ifba_nome = 'IFBA - Campus Camaçari'
latitude_ifba = -12.689406908116812
longitude_ifba =-38.253436743984935
htmlcode = """<div>
              <img src="IFBACAM.jpg" alt="IFBA - Campus Camaçari" width="230" height="172">
              <br /><span>IFBA - Campus Camaçarir</span></div>"""
tooltip = "IFBA - Campus Camaçari"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)

icone = folium.Icon(color='green')
ifba_nome = 'IFBA - Campus Feira De Santana'
latitude_ifba = -12.28007090899142 
longitude_ifba =-38.88867108055882
htmlcode = """<div>
              <img src="IFBAFS.jpg" alt="IFBA - Campus Feira De Santana" width="230" height="172">
              <br /><span>IFBA - Campus Feira De Santana</span></div>"""
tooltip = "IFBA - Campus Feira De Santana"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)

icone = folium.Icon(color='green')
ifba_nome = 'IFBA - Campus Jequié'
latitude_ifba = -13.85195533720813 
longitude_ifba =-40.11694642274262
htmlcode = """<div>
              <img src="IFBAJEQ.jpg" alt="IFBA - Campus Jequié" width="230" height="172">
              <br /><span>IFBA - Campus Jequié</span></div>"""
tooltip = "IFBA - Campus Jequié"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)



icone = folium.Icon(color='green')
ifba_nome = 'IFBA - Ilhéus'
latitude_ifba = -14.80266294375127 
longitude_ifba =-39.1485417036855
htmlcode = """<div>
              <img src="IFBAILHEUS.jpg" alt="IFBA - Ilhéus" width="230" height="172">
              <br /><span>IFBA - Campus Jequié</span></div>"""
tooltip = "IFBA - Ilhéus"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)

, 

icone = folium.Icon(color='green')
ifba_nome = 'IFBA - Campus Juazeiro'
latitude_ifba = -9.450397211285967
longitude_ifba =-40.52323616143822
htmlcode = """<div>
              <img src="IFBAJUA.jpg" alt="IFBA - Campus Juazeiro" width="230" height="172">
              <br /><span>IFBA - Campus Juazeiro</span></div>"""
tooltip = "IFBA - Campus Juazeiro"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)


icone = folium.Icon(color='green')
ifba_nome = 'IFBA - Campus Santo Amaro'
latitude_ifba = -12.545328009665358
longitude_ifba =-38.72124087858575
htmlcode = """<div>
              <img src="IFBASANTOAM.jpg" alt="IFBA - Campus Santo Amaro" width="230" height="172">
              <br /><span>IFBA - Campus Santo Amaro</span></div>"""
tooltip = "IFBA - Campus Santo Amaro"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)


icone = folium.Icon(color='green')
ifba_nome = 'IFBA - Campus Vitória da Conquista'
latitude_ifba = -14.823275276859697
longitude_ifba =-40.61071654773341
htmlcode = """<div>
              <img src="IFBAVITORIA.jpg" alt="IFBA - Campus Vitória da Conquista" width="230" height="172">
              <br /><span>IFBA - Campus Vitória da Conquista</span></div>"""
tooltip = "IFBA - Campus Vitória da Conquista"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)



icone = folium.Icon(color='green')
ifba_nome = 'IFBA Jacobina'
latitude_ifba = -11.181861581999597
longitude_ifba =-40.536003274858835
htmlcode = """<div>
              <img src="IFBAJACOBINA.jpg" alt="IFBA Jacobina" width="230" height="172">
              <br /><span>IFBA Jacobina</span></div>"""
tooltip = "IFBA Jacobina"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)



# Localização dos IFBAIANOS


icone = folium.Icon(color='lightgreen')
ifba_nome = "Instituto Federal Baiano - Reitoria IF Baiano"
latitude_ifba = -12.941633788034332
longitude_ifba = -38.357865613685824
htmlcode = """<div>
              <img src="IFBAIANOREI.jpg" alt="Instituto Federal Baiano - Reitoria IF Baiano" width="230" height="172">
              <br /><span>Instituto Federal Baiano - Reitoria IF Baiano</span></div>"""
tooltip = "Instituto Federal Baiano - Reitoria IF Baiano"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)


icone = folium.Icon(color='lightgreen')
ifba_nome = "Ifbaiano"
latitude_ifba = -12.893446463179599
longitude_ifba = -38.508927615535974
htmlcode = """<div>
              <img src="IFBAIANO.jpg" alt="Ifbaiano" width="230" height="172">
              <br /><span>Ifbaiano</span></div>"""
tooltip = "Ifbaiano"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)


icone = folium.Icon(color='lightgreen')
ifba_nome = ["IF Baiano Campus Catu"]
latitude_ifba = -12.34064581215707
longitude_ifba = -38.37434510479675
htmlcode = """<div>
              <img src="IFBAIANOCATU.jpg" alt="IF Baiano Campus Catu" width="230" height="172">
              <br /><span>IF Baiano Campus Catu</span></div>"""
tooltip = "IF Baiano Campus Catu"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)


icone = folium.Icon(color='lightgreen')
ifba_nome = "IF Baiano Governador Mangabeira"
latitude_ifba = -12.591842236567532
longitude_ifba = -39.01150324426245
htmlcode = """<div>
              <img src="IFBAIANOGM.jpg" alt="IF Baiano Governador Mangabeira" width="230" height="172">
              <br /><span>IF Baiano Governador Mangabeira</span></div>"""
tooltip = "IF Baiano Governador Mangabeira"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)




icone = folium.Icon(color='lightgreen')
ifba_nome = "IF Baiano - Campus Alagoinhas"
latitude_ifba = -12.137861742252252
longitude_ifba = -38.38610438065132
htmlcode = """<div>
              <img src="IFBAIANOAL.jpg" alt="IF Baiano - Campus Alagoinhas" width="230" height="172">
              <br /><span>IF Baiano - Campus Alagoinhas</span></div>"""
tooltip = "IF Baiano - Campus Alagoinhas"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)




icone = folium.Icon(color='lightgreen')
ifba_nome = "IF Baiano - Campus Valença"
latitude_ifba = -13.35563625721898
longitude_ifba =  -39.060581871484715
htmlcode = """<div>
              <img src="IFBAIANOVAL.jpg" alt="IF Baiano - Campus Valença" width="230" height="172">
              <br /><span>IF Baiano - Campus Valença</span></div>"""
tooltip = "IF Baiano - Campus Valença"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)



icone = folium.Icon(color='lightgreen')
ifba_nome = "IF Baiano Campus Santa Inês"
latitude_ifba = -13.264283868577987
longitude_ifba = -39.77314944407744
htmlcode = """<div>
              <img src="IFBAIANOSI.jpeg" alt="IF Baiano Campus Santa Inês" width="230" height="172">
              <br /><span>IF Baiano Campus Santa Inês</span></div>"""
tooltip = "IF Baiano Campus Santa Inês"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)



icone = folium.Icon(color='lightgreen')
ifba_nome = " IF Baiano - Catu"
latitude_ifba = -12.349303039920974
longitude_ifba =  -38.35884016166133
htmlcode = """<div>
              <img src="IFBAIANOCATU.jpg" alt="IF Baiano - Catu" width="230" height="172">
              <br /><span>IF Baiano - Catu</span></div>"""
tooltip = "IF Baiano - Catu"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)


icone = folium.Icon(color='lightgreen')
ifba_nome = " IF Baiano Campus Uruçuca"
latitude_ifba = -14.44267368202054 
longitude_ifba = -39.32766049438935
htmlcode = """<div>
              <img src="IFBAIANOURUCUCA.jpeg" alt="IF Baiano Campus Uruçuca" width="230" height="172">
              <br /><span>IF Baiano Campus Uruçuca</span></div>"""
tooltip = "IF Baiano Campus Uruçuca"
pin = folium.Marker(location=(latitude_ifba,longitude_ifba),popup=htmlcode,icon=icone, tooltip=tooltip
).add_to(bahia)




#Exibe o Mapa
bahia

#Grava o Mapa
bahia.save("MAPAIFBA.HTML")
